# %% [markdown]
# # Demo: SER pipeline
#
# This minimal demo shows the preprocessing -> baseline -> fusion steps. Run the scripts in `src/` as shown.

# %%
# Example commands (run in shell)\n!python src/build_metadata.py\n!python src/make_spectrograms.py\n!python src/extract_acoustic.py\n!python src/make_splits.py\n# Then train a baseline:\n# !python src/train_vgg_spec.py\n# Or acoustic baseline:\n# !python src/train_cnn1d_acoustic.py\n# Fusion:\n# !python src/train_fusion.py
